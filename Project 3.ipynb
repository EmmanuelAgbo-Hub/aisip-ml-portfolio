# %% [markdown]
# ## Project
# ### A program using a for loop that processes a list of African city populations and finds the top 3 largest
#
# ###### AUTHOR: AGBO EMMANUEL SUNDAY

# %%
# Data collected from the web
# Most Populous City by African Country (2026 Projections)
# Format: "Country": ("City Name", Population_Count)
africa_cities_2026 = {
    "Algeria": ("Algiers", 4400000),
    "Angola": ("Luanda", 10400000),
    "Benin": ("Cotonou", 2225000),
    "Botswana": ("Gaborone", 295000),
    "Burkina Faso": ("Ouagadougou", 3550000),
    "Burundi": ("Bujumbura", 1320000),
    "Cabo Verde": ("Praia", 165000),
    "Cameroon": ("Douala", 3950000),
    "Central African Republic": ("Bangui", 1740000),
    "Chad": ("N'Djamena", 2025000),
    "Comoros": ("Moroni", 75000),
    "Congo Republic": ("Brazzaville", 2550000),
    "DR Congo": ("Kinshasa", 16900000),
    "Djibouti": ("Djibouti City", 625000),
    "Egypt": ("Cairo", 23200000),
    "Equatorial Guinea": ("Bata", 330000),
    "Eritrea": ("Asmara", 1120000),
    "Eswatini": ("Manzini", 125000),
    "Ethiopia": ("Addis Ababa", 4950000),
    "Gabon": ("Libreville", 915000),
    "Gambia": ("Banjul (Serekunda)", 1210000),
    "Ghana": ("Accra", 7050000),
    "Guinea": ("Conakry", 4000000),
    "Guinea-Bissau": ("Bissau", 730000),
    "Ivory Coast": ("Abidjan", 7300000),
    "Kenya": ("Nairobi", 7150000),
    "Lesotho": ("Maseru", 350000),
    "Liberia": ("Monrovia", 2000000),
    "Libya": ("Tripoli", 1930000),
    "Madagascar": ("Antananarivo", 3250000),
    "Malawi": ("Lilongwe", 1250000),
    "Mali": ("Bamako", 5950000),
    "Mauritania": ("Nouakchott", 1550000),
    "Mauritius": ("Port Louis", 155000),
    "Morocco": ("Casablanca", 4500000),
    "Mozambique": ("Maputo", 2650000),
    "Namibia": ("Windhoek", 490000),
    "Niger": ("Niamey", 1580000),
    "Nigeria": ("Lagos", 21900000),
    "Rwanda": ("Kigali", 2050000),
    "Sao Tome & Principe": ("São Tomé", 85000),
    "Senegal": ("Dakar", 4375000),
    "Seychelles": ("Victoria", 30000),
    "Sierra Leone": ("Freetown", 1460000),
    "Somalia": ("Mogadishu", 2325000),
    "South Africa": ("Johannesburg", 15100000),
    "South Sudan": ("Juba", 575000),
    "Sudan": ("Khartoum", 7400000),
    "Tanzania": ("Dar es Salaam", 6900000),
    "Togo": ("Lomé", 2725000),
    "Tunisia": ("Tunis", 2775000),
    "Uganda": ("Kampala", 5350000),
    "Zambia": ("Lusaka", 3100000),
    "Zimbabwe": ("Harare", 2700000)
}

# %%
# Extract the cities and their respective populations from the dictionary above
cities = []
population = []
countries = []

for key, value in africa_cities_2026.items():
    cities.append(value[0])
    population.append(value[1])
    countries.append(key)

# Sort the population list in a descending so as to easily locate the top 3 largest values
population.sort(reverse= True)
top_3_largest = population[:3]

# Extract the population values again easy manipulation
population_2 = []
for key, value in africa_cities_2026.items():
    population_2.append(value[1])

print('The top 3 largest cities in Africa')
print('COUNTRY --> CITIES  --> POPULATION')
print(f'{countries[population_2.index(top_3_largest[0])]}   --> {cities[population_2.index(top_3_largest[0])]}   --> {top_3_largest[0]}')
print(f'{countries[population_2.index(top_3_largest[1])]} --> {cities[population_2.index(top_3_largest[1])]}   --> {top_3_largest[1]}')
print(f'{countries[population_2.index(top_3_largest[2])]}--> {cities[population_2.index(top_3_largest[2])]} -->{top_3_largest[2]}')
# Out:
# The top 3 largest cities in Africa
# COUNTRY --> CITIES  --> POPULATION
# Egypt   --> Cairo   --> 23200000
# Nigeria --> Lagos   --> 21900000
# DR Congo--> Kinshasa -->16900000
