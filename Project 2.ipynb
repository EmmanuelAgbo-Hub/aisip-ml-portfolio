# %% [markdown]
# ## Project
# ### A program using if/elif/else that categorises African countries by GDP per capita into ‘Low’, ‘Middle’, ‘High’ income
# ###### AUTHOR: AGBO EMMANUEL SUNDAY

# %%
# African Countries GDP per Capita Projections (USD) - 2026
# Source: IMF / World Economic Outlook
africa_gdp_per_capita_2026 = {
    "Seychelles": 21956.0,
    "Mauritius": 12519.0,
    "Gabon": 9303.0,
    "Equatorial Guinea": 8229.0,
    "Botswana": 6943.0,
    "Libya": 6866.0,
    "South Africa": 6122.0,
    "Algeria": 5631.0,
    "Cabo Verde": 5273.0,
    "Namibia": 4413.0,
    "Tunisia": 4350.0,
    "Morocco": 3993.0,
    "Eswatini": 3936.0,
    "Djibouti": 3496.0,
    "Egypt": 3191.0,
    "Ghana": 3193.0,
    "Sao Tome & Principe": 3102.0,
    "Zimbabwe": 3071.0,
    "Ivory Coast": 3016.0,
    "Angola": 2931.0,
    "Mauritania": 2582.0,
    "Kenya": 2549.0,
    "Congo Republic": 2420.0,
    "Cameroon": 2027.0,
    "Senegal": 1921.0,
    "Comoros": 1773.0,
    "Guinea": 1741.0,
    "Benin": 1635.0,
    "Zambia": 1353.0,
    "Uganda": 1353.0,
    "Tanzania": 1302.0,
    "Togo": 1215.0,
    "Chad": 1209.0,
    "Mali": 1094.0,
    "Rwanda": 1069.0,
    "Ethiopia": 994.0,
    "Sierra Leone": 980.0,
    "Burkina Faso": 978.0,
    "Lesotho": 972.0,
    "Guinea-Bissau": 963.0,
    "Liberia": 904.0,
    "Gambia": 890.0,
    "Nigeria": 807.0,
    "Niger": 789.0,
    "DR Congo": 772.0,
    "Somalia": 763.0,
    "Sudan": 763.0,
    "Malawi": 721.0,
    "Mozambique": 720.0,
    "Madagascar": 653.0,
    "Central African Republic": 651.0,
    "South Sudan": 369.0,
    "Burundi": 256.0
}

# My metrics for the categorisation
# low = 3040 or below
# middle = above 3040 and below 10000
# High = above 10000

# Looping through the dictionary of all the African countries and their GDP per Capita to categorise them
for key, value in africa_gdp_per_capita_2026.items():
    print()
    if value <= 3040:
        print(f'{key} --> Low income')
    elif value > 3040 and value < 10000:
        print(f'{key} --> Middle income')
    else:
        print(f'{key} --> High income')
# Out:
# Seychelles --> High income
#
# Mauritius --> High income
#
# Gabon --> Middle income
#
# Equatorial Guinea --> Middle income
#
# Botswana --> Middle income
#
# Libya --> Middle income
#
# South Africa --> Middle income
#
# Algeria --> Middle income
#
# Cabo Verde --> Middle income
#
# Namibia --> Middle income
#
# Tunisia --> Middle income
#
# Morocco --> Middle income
#
# Eswatini --> Middle income
#
# Djibouti --> Middle income
#
# Egypt --> Middle income
#
# Ghana --> Middle income
#
# Sao Tome & Principe --> Middle income
#
# Zimbabwe --> Middle income
#
# Ivory Coast --> Low income
#
# Angola --> Low income
#
# Mauritania --> Low income
#
# Kenya --> Low income
#
# Congo Republic --> Low income
#
# Cameroon --> Low income
#
# Senegal --> Low income
#
# Comoros --> Low income
#
# Guinea --> Low income
#
# Benin --> Low income
#
# Zambia --> Low income
#
# Uganda --> Low income
#
# Tanzania --> Low income
#
# Togo --> Low income
#
# Chad --> Low income
#
# Mali --> Low income
#
# ...
