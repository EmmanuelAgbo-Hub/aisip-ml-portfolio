# %% [markdown]
# ## Project Assignment
# #### A program using a dictionary that stores 10 African countries with their capitals and lets a user look up any country
# ##### AUTHOR: AGBO EMMANUEL SUNDAY

# %%
countries_cap = {
    "Nigeria": "Abuja",
    "Ghana": "",
    "South Africa": "",
    "Algeria": "",
    "Egypt": "",
    "Rwanda": "",
    "Cameroon": "",
    "Angola": "",
    "Kenya": "",
    "Ethiopia": "" 
}

# %%
capital = countries_cap['Ghana']
print(f"The capital Nigeria is {capital}")
# Out:
# The capital Nigeria is
